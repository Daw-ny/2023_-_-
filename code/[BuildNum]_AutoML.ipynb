# %% [markdown]
# ## Import

# %%
# preprocessing
import numpy as np
import pandas as pd
import tqdm
import random
import os

# imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# model learning
from sklearn.model_selection import train_test_split
from supervised.automl import AutoML
from sklearn.utils.class_weight import compute_sample_weight
import statsmodels.api as sm

# 평가 지표
from sklearn.metrics import mean_absolute_error

# 모델 저장
import pickle

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')
building_info = pd.read_csv('../data/building_info.csv')

# %% [markdown]
# ## Change Names

# %%
#translation_dict = {
#    '건물기타': 'Other Buildings',
#    '공공': 'Public',
#    '대학교': 'University',
#    '데이터센터': 'Data Center',
#    '백화점및아울렛': 'Department Store and Outlet',
#    '병원': 'Hospital',
#    '상용': 'Commercial',
#    '아파트': 'Apartment',
#    '연구소': 'Research Institute',
#    '지식산업센터': 'Knowledge Industry Center',
#    '할인마트': 'Discount Mart',
#    '호텔및리조트': 'Hotel and Resort'
#}

#building_info['건물유형'] = building_info['건물유형'].replace(translation_dict)
# building_info.drop('Unnamed: 0', axis = 1 , inplace=True)

# %%
train_df.columns = ['num_date_time', '건물번호', '일시', '기온', '강수량', '풍속', '습도',
       '일조', '일사', '전력소비량']

# %%
test_df.columns = ['num_date_time', '건물번호', '일시', '기온', '강수량', '풍속', '습도']

# %%
building_info.columns = ['건물번호', '건물유형', '연면적', '냉방면적', '태양광용량', 'ESS저장용량',
       'PCS용량']

# %% [markdown]
# ## Encoding

# %%
# one hot encoding 생성
#building_info = pd.get_dummies(building_info, columns=['건물유형'], drop_first=True)

# %%
# LabelEncoder를 객체로 생성
#encoder = LabelEncoder()

# fit, transform 메소드를 통한 레이블 인코딩
#encoder.fit(building_info['건물유형'])
#building_info['건물유형'] = encoder.transform(building_info['건물유형'])

# %% [markdown]
# ## Merge building info

# %%
#building_info['태양광용량'][building_info['태양광용량'] == '-'] = np.nan
#building_info['ESS저장용량'][building_info['ESS저장용량'] == '-'] = np.nan
#building_info['PCS용량'][building_info['PCS용량'] == '-'] = np.nan

# %%
# 태양광 사용하는지 마는지 여부
#building_info['태양광사용여부'] = 0

# %%
#building_info['태양광사용여부'][(building_info['태양광용량'].notnull()) | (building_info['ESS저장용량'].notnull()) | (building_info['PCS용량'].notnull())] = 1

# %%
train_df = pd.merge(train_df, building_info, on='건물번호', how='left')
test_df = pd.merge(test_df, building_info, on='건물번호', how='left')

# %% [markdown]
# ## Train Data Pre-Processing

# %%
train_df.isna().sum()
# Out:
# num_date_time         0
# 건물번호                  0
# 일시                    0
# 기온                    0
# 강수량              160069
# 풍속                   19
# 습도                    9
# 일조                75182
# 일사                87913
# 전력소비량                 0
# 건물유형                  0
# 연면적                   0
# 냉방면적                  0
# 태양광용량                 0
# ESS저장용량               0
# PCS용량                 0
# dtype: int64

# %% [markdown]
# - 결측치가 시급하다. 아무리봐도 처리 해야할 것 같다.

# %%
#시계열 특성을 학습에 반영하기 위해 일시를 월, 일, 시간으로 나눕니다
train_df['월'] = train_df['일시'].apply(lambda x : int(x[4:6]))
#train_df['일'] = train_df['일시'].apply(lambda x : int(x[6:8]))
train_df['시'] = train_df['일시'].apply(lambda x : int(x[9:11]))

# %%
train_df['일시'] = pd.to_datetime(train_df['일시'], format='%Y%m%d %H')

# %%
# 요일 추가 (0이 월요일 6이 일요일)
train_df['주'] = train_df['일시'].dt.dayofweek

# %%
#train_df['일조'][(train_df['일조'].isna()) & ((train_df['시'] <= 5) | (train_df['시'] >= 21))] = 0
#train_df['일사'][(train_df['일사'].isna()) & ((train_df['시'] <= 5) | (train_df['시'] >= 21))] = 0

# %%
train_df['풍속'][train_df['풍속'].isna()] = 0
train_df['습도'][train_df['습도'].isna()] = 0

# %%
# imputation for mice
#imputer_mice = IterativeImputer(random_state=42)
#imputer_mice.fit(train_df[['기온', '풍속', '습도', '일조', '일사']])

# 데이터 변환 (array로 반환하기 때문에 필요에 맞는 형태로 변환 후 사용)
#train_df[['기온', '풍속', '습도', '일조', '일사']] = pd.DataFrame(imputer_mice.transform(train_df[['기온', '풍속', '습도', '일조', '일사']]),
#                         columns=['기온', '풍속', '습도', '일조', '일사'])

# %%
# 숫자 보정
#train_df['일조'][train_df['일조'] < 0] = 0
#train_df['일사'][train_df['일사'] < 0] = 0

# %%
# 변수 정리
train_df2 = train_df.drop(columns=['num_date_time', '일시',
                                 '태양광용량','ESS저장용량','PCS용량', '강수량', '일조', '일사', '건물유형'])

# %%
# 강수량 결측치는 0으로 보정 -> 비 안왔을것이라 예상하고 진행함
# train_df2['강수량(mm)'][train_df2['강수량(mm)'].isna()] = 0

# %%
# imputation for mice
#imputer_mice = IterativeImputer(random_state=42)
#imputer_mice.fit(train_df2)

# 데이터 변환 (array로 반환하기 때문에 필요에 맞는 형태로 변환 후 사용)
#train_df2 = pd.DataFrame(imputer_mice.transform(train_df2),
#                         columns=train_df2.columns)

# %%
# 그냥 0으로 채우기
#train_df2[train_df2.isna()] = 0

# %% [markdown]
# ## Append Value

# %%
# 온도에 따른 포화 수증기압(mb)
#train_df2['포화수증기압'] = 6.11*10**((7.5*train_df2['기온'])/(237.3 + train_df2['기온']))

# %%
# 현재 대기의 수증기압(mb)
#train_df2['대기압'] = train_df2['습도'] * train_df2['포화수증기압'] / 100

# %%
# 절대습도(g/m^3)
#train_df2['절대습도'] = (0.794*train_df2['대기압'])/(1+0.00366*train_df2['기온'])

# %%
# 공기중의 혼합비(mb)
#train_df2['혼합비'] = 0.622 * train_df2['대기압']/(1013.25 - train_df2['대기압'])

# %%
# 습구온도
#train_df2['습구온도'] = train_df2['기온']*np.arctan(0.151977+(train_df2['습도'] + 8.313659)**0.5) + np.arctan(train_df2['기온'] + train_df2['습도']) - np.arctan(train_df2['습도'] - 1.676331) +0.00391838*(train_df2['습도']**1.5)*np.arctan(0.023101*train_df2['습도'])-4.686035

# %%
# 불쾌지수
#train_df2['불쾌지수'] = 9/5*train_df2['기온'] - 0.55*(1-0.01*train_df2['습도'])*(9/5*train_df2['기온'] - 26) + 32

# %%
# 더위체감지수
#train_df2['더위체감지수'] = -0.24418 + 0.553991*train_df2['습구온도'] + 0.455346*train_df2['기온'] - 0.00217*train_df2['습구온도']**2 + 0.002782*train_df2['습구온도']*train_df2['기온'] + 3

# %%
# np.select
#condlist = [
#    (train_df2['더위체감지수'] < 21),
#    (train_df2['더위체감지수'] < 25) & (train_df2['더위체감지수'] >= 21),
#    (train_df2['더위체감지수'] < 28) & (train_df2['더위체감지수'] >= 25),
#    (train_df2['더위체감지수'] < 31) & (train_df2['더위체감지수'] >= 28),
#    (train_df2['더위체감지수'] >= 31)
#            ]

#choicelist = [0, 1, 2, 3, 4]

# %%
# 범주형 체감지수
#train_df2['더위체감지수_범주'] = np.select(condlist, choicelist)

# %%
# 열지수
#train_df2['열지수'] = (5/9)*(-42.379 + (2.04901523 * ((9/5)*train_df2['기온']+32)) + (10.14333127 * train_df2['습도']) - (0.22475541 * ((9/5)*train_df2['기온']+32)*train_df2['습도']) - (6.83783e-3 * ((9/5)*train_df2['기온']+32)**2) - (5.481717e-2 * train_df2['습도']**2) + (1.22874e-3 * ((9/5)*train_df2['기온']+32)**2*train_df2['습도']) + (8.5282e-4 * ((9/5)*train_df2['기온']+32)*train_df2['습도']**2) - (1.99e-6 * ((9/5)*train_df2['기온']+32)**2*train_df2['습도']**2) - 32)

# %%
# 평균냉방면적
#train_df2['평균냉방면적'] = train_df2['냉방면적']/train_df2['연면적']

# %%
# onehot 주
#train_df2 = pd.get_dummies(train_df2, columns=['주'], drop_first=True)

# %%
# 훈련 및 테스트 데이터 셋
train_x = train_df2[train_df2.columns.difference(['전력소비량', '냉방면적', '연면적'])]
train_y = train_df2['전력소비량']

# %% [markdown]
# # BoxCox

# %%
# 가중치
boxcox = 0.21

# %%
# 적용
train_y_boxcox = train_y**boxcox

# %% [markdown]
# ## Test Data Pre-Processing

# %%
test_df['월'] = test_df['일시'].apply(lambda x : int(x[4:6]))
#test_df['일'] = test_df['일시'].apply(lambda x : int(x[6:8]))
test_df['시'] = test_df['일시'].apply(lambda x : int(x[9:11]))

# %%
test_df['일시'] = pd.to_datetime(test_df['일시'], format='%Y%m%d %H')

# %%
# 요일 추가 (0이 월요일 6이 일요일)
test_df['주'] = test_df['일시'].dt.dayofweek

# %%
# 없는 변수 추가하기
#test_df['일조'] = np.nan
#test_df['일사'] = np.nan

# 데이터 변환 (array로 반환하기 때문에 필요에 맞는 형태로 변환 후 사용)
#test_df[['기온', '풍속', '습도', '일조', '일사']] = pd.DataFrame(imputer_mice.transform(test_df[['기온', '풍속', '습도', '일조', '일사']]),
#                         columns=['기온', '풍속', '습도', '일조', '일사'])

# %%
# 숫자 보정
#test_df['일조'][test_df['일조'] < 0] = 0
#test_df['일사'][test_df['일사'] < 0] = 0

# %%
# 변수 정리
test_df2 = test_df.drop(columns=['num_date_time', '일시',
                                 '태양광용량','ESS저장용량','PCS용량', '강수량', '건물유형', '연면적',
                                '냉방면적'])

# %% [markdown]
# ## Append Value

# %%
# 온도에 따른 포화 수증기압(mb)
#test_df2['포화수증기압'] = 6.11*10**((7.5*test_df2['기온'])/(237.3 + test_df2['기온']))

# %%
# 현재 대기의 수증기압(mb)
#test_df2['대기압'] = test_df2['습도'] * test_df2['포화수증기압'] / 100

# %%
# 절대습도(g/m^3)
#test_df2['절대습도'] = (0.794*test_df2['대기압'])/(1+0.00366*test_df2['기온'])

# %%
# 공기중의 혼합비(mb)
#test_df2['혼합비'] = 0.622 * test_df2['대기압']/(1013.25 - test_df2['대기압'])

# %%
# 습구온도
#test_df2['습구온도'] = test_df2['기온']*np.arctan(0.151977+(test_df2['습도'] + 8.313659)**0.5) + np.arctan(test_df2['기온'] + test_df2['습도']) - np.arctan(test_df2['습도'] - 1.676331) +0.00391838*(test_df2['습도']**1.5)*np.arctan(0.023101*test_df2['습도'])-4.686035

# %%
# 불쾌지수
#test_df2['불쾌지수'] = 9/5*test_df2['기온'] - 0.55*(1-0.01*test_df2['습도'])*(9/5*test_df2['기온'] - 26) + 32

# %%
# 더위체감지수
#test_df2['더위체감지수'] = -0.24418 + 0.553991*test_df2['습구온도'] + 0.455346*test_df2['기온'] - 0.00217*test_df2['습구온도']**2 + 0.002782*test_df2['습구온도']*test_df2['기온'] + 3

# %%
# np.select
#condlist = [
#    (test_df2['더위체감지수'] < 21),
#    (test_df2['더위체감지수'] < 25) & (test_df2['더위체감지수'] >= 21),
#    (test_df2['더위체감지수'] < 28) & (test_df2['더위체감지수'] >= 25),
#    (test_df2['더위체감지수'] < 31) & (test_df2['더위체감지수'] >= 28),
#    (test_df2['더위체감지수'] >= 31)
#           ]

#choicelist = [0, 1, 2, 3, 4]

# %%
# 범주형 체감지수
#test_df2['더위체감지수_범주'] = np.select(condlist, choicelist)

# %%
# 열지수
#test_df2['열지수'] = (5/9)*(-42.379 + (2.04901523 * ((9/5)*test_df2['기온']+32)) + (10.14333127 * test_df2['습도']) - (0.22475541 * ((9/5)*test_df2['기온']+32)*test_df2['습도']) - (6.83783e-3 * ((9/5)*test_df2['기온']+32)**2) - (5.481717e-2 * test_df2['습도']**2) + (1.22874e-3 * ((9/5)*test_df2['기온']+32)**2*test_df2['습도']) + (8.5282e-4 * ((9/5)*test_df2['기온']+32)*test_df2['습도']**2) - (1.99e-6 * ((9/5)*test_df2['기온']+32)**2*test_df2['습도']**2) - 32)

# %%
# 평균냉방면적
#test_df2['평균냉방면적'] = test_df2['냉방면적']/test_df2['연면적']

# %%
# onehot 주
#test_df2 = pd.get_dummies(test_df2, columns=['주'], drop_first=True)

# %%
# test_df2 = std_scaler.fit_transform(test_df2)

# %%
# 훈련 및 테스트 데이터 셋
#test_df2 = test_df2[test_df2.columns.difference(['냉방면적', '연면적', '습도', '월', '건물번호', '기온'])]

# %%
test_df2
# Out:
#        건물번호    기온   풍속  습도  월   시  주
# 0         1  23.5  2.2  72  8   0  3
# 1         1  23.0  0.9  72  8   1  3
# 2         1  22.7  1.5  75  8   2  3
# 3         1  22.1  1.3  78  8   3  3
# 4         1  21.8  1.0  77  8   4  3
# ...     ...   ...  ...  .. ..  .. ..
# 16795   100  22.5  0.9  84  8  19  2
# 16796   100  20.7  0.4  95  8  20  2
# 16797   100  20.2  0.4  98  8  21  2
# 16798   100  20.1  1.1  97  8  22  2
# 16799   100  19.1  0.1  99  8  23  2
#
# [16800 rows x 7 columns]

# %%
train_x
# Out:
#         건물번호    기온    습도   시  월  주   풍속
# 0          1  18.6  42.0   0  6  2  0.9
# 1          1  18.0  45.0   1  6  2  1.1
# 2          1  17.7  45.0   2  6  2  1.5
# 3          1  16.7  48.0   3  6  2  1.4
# 4          1  18.4  43.0   4  6  2  2.8
# ...      ...   ...   ...  .. .. ..  ...
# 203995   100  23.1  86.0  19  8  2  0.9
# 203996   100  22.4  86.0  20  8  2  1.3
# 203997   100  21.3  92.0  21  8  2  1.0
# 203998   100  21.0  94.0  22  8  2  0.3
# 203999   100  20.7  95.0  23  8  2  0.1
#
# [204000 rows x 7 columns]

# %% [markdown]
# ## Regression Model Fit by

# %%
# 건물 번호별로 fitting하기
preds = pd.DataFrame()
for i in tqdm.notebook.tqdm(range(53, 71)):
    # train x, y 만들고 적합하기
    globals()['train_buildnum{}_x'.format(i)] = train_x[['기온','습도','시','월','주','풍속']][train_x['건물번호'] == i]
    globals()['train_buildnum{}_y'.format(i)] = train_y_boxcox[train_x['건물번호'] == i]
    
    # automl modeling
    automl = AutoML(mode="Compete",
                    algorithms=["Baseline",
                                "CatBoost",
                                "Xgboost",
                                "Random Forest",
                                "Extra Trees",
                                "LightGBM",
                                "Neural Network"], 
                    ml_task = "regression",
                    eval_metric = 'mae',
                    random_state = 42,
                    results_path = '../model/split_build/' + str(i) + '/'
                   )
    
    # fitting
    automl.fit(globals()['train_buildnum{}_x'.format(i)], globals()['train_buildnum{}_y'.format(i)])
    
    # predict
    globals()['pred_buildnum{}'.format(i)] = automl.predict(test_df2[['기온','습도','시','월','주','풍속']][test_df2['건물번호'] == i])
    
    # 혹시몰라서 saving
    pd.DataFrame(globals()['pred_buildnum{}'.format(i)]).to_csv('../data/split_build/split_build{}.csv'.format(i), index = False)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# AutoML directory: ../model/split_build/53/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.170836 trained in 0.34 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.558141 trained in 1.56 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.100976 trained in 8.68 seconds
# 3_Default_Xgboost mae 0.093548 trained in 7.74 seconds
# 4_Default_CatBoost mae 0.090771 trained in 12.82 seconds
# 5_Default_NeuralNetwork mae 0.12812 trained in 5.93 seconds
# 6_Default_RandomForest mae 0.168613 trained in 17.51 seconds
# 7_Default_ExtraTrees mae 0.271724 trained in 7.48 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.126618 trained in 6.73 seconds
# 8_Xgboost mae 0.127255 trained in 8.54 seconds
# 26_CatBoost mae 0.088057 trained in 16.82 seconds
# 35_RandomForest mae 0.167572 trained in 10.03 seconds
# 44_ExtraTrees mae 0.254155 trained in 7.84 seconds
# 53_NeuralNetwork mae 0.170545 trained in 5.68 seconds
# 18_LightGBM mae 0.09485 trained in 5.04 seconds
# 9_Xgboost mae 0.130959 trained in 5.49 seconds
# 27_CatBoost mae 0.091249 trained in 10.07 seconds
# 36_RandomForest mae 0.152489 trained in 9.2 seconds
# 45_ExtraTrees mae 0.269909 trained in 14.0 seconds
# 54_NeuralNetwork mae 0.138163 trained in 7.15 seconds
# 19_LightGBM mae 0.1063 trained in 7.33 seconds
# 10_Xgboost mae 0.123051 trained in 12.85 seconds
# 28_CatBoost mae 0.084692 trained in 50.53 seconds
# 37_RandomForest mae 0.209352 trained in 9.02 seconds
# 46_ExtraTrees mae 0.328798 trained in 8.56 seconds
# 55_NeuralNetwork mae 0.156343 trained in 11.69 seconds
# 20_LightGBM mae 0.101417 trained in 15.9 seconds
# 11_Xgboost mae 0.119518 trained in 7.53 seconds
# 29_CatBoost mae 0.105348 trained in 8.39 seconds
# 38_RandomForest mae 0.180152 trained in 12.14 seconds
# 47_ExtraTrees mae 0.307295 trained in 9.61 seconds
# 56_NeuralNetwork mae 0.156914 trained in 8.35 seconds
# 21_LightGBM mae 0.130275 trained in 7.84 seconds
# 12_Xgboost mae 0.129707 trained in 10.24 seconds
# 30_CatBoost mae 0.090302 trained in 45.33 seconds
# 39_RandomForest mae 0.201823 trained in 10.95 seconds
# 48_ExtraTrees mae 0.376286 trained in 11.7 seconds
# 57_NeuralNetwork mae 0.140263 trained in 9.31 seconds
# 22_LightGBM mae 0.101027 trained in 9.47 seconds
# 13_Xgboost mae 0.112536 trained in 7.74 seconds
# 31_CatBoost mae 0.098292 trained in 12.49 seconds
# 40_RandomForest mae 0.181144 trained in 15.48 seconds
# 49_ExtraTrees mae 0.300182 trained in 10.75 seconds
# 58_NeuralNetwork mae 0.132082 trained in 10.17 seconds
# 23_LightGBM mae 0.111528 trained in 7.14 seconds
# 14_Xgboost mae 0.112814 trained in 7.14 seconds
# 32_CatBoost mae 0.089693 trained in 11.31 seconds
# 41_RandomForest mae 0.141094 trained in 11.92 seconds
# 50_ExtraTrees mae 0.197895 trained in 10.9 seconds
# 59_NeuralNetwork mae 0.136997 trained in 7.81 seconds
# 24_LightGBM mae 0.094923 trained in 7.64 seconds
# 15_Xgboost mae 0.138189 trained in 11.52 seconds
# 33_CatBoost mae 0.087386 trained in 23.3 seconds
# 42_RandomForest mae 0.207744 trained in 16.88 seconds
# 51_ExtraTrees mae 0.342386 trained in 12.1 seconds
# 60_NeuralNetwork mae 0.14655 trained in 9.7 seconds
# 25_LightGBM mae 0.095892 trained in 6.67 seconds
# 16_Xgboost mae 0.120125 trained in 12.38 seconds
# 34_CatBoost mae 0.09367 trained in 26.0 seconds
# 43_RandomForest mae 0.181328 trained in 15.19 seconds
# 52_ExtraTrees mae 0.293838 trained in 11.6 seconds
# 61_NeuralNetwork mae 0.138883 trained in 9.02 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 주_multiply_월
# Add Golden Feature: 주_ratio_월
# Add Golden Feature: 월_ratio_주
# Add Golden Feature: 기온_ratio_주
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 주_ratio_기온
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 월_diff_주
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 주_diff_풍속
# Created 10 Golden Features in 12.57 seconds.
# 28_CatBoost_GoldenFeatures mae 0.083014 trained in 123.94 seconds
# 33_CatBoost_GoldenFeatures mae 0.084746 trained in 36.9 seconds
# 26_CatBoost_GoldenFeatures mae 0.086427 trained in 36.1 seconds
# * Step kmeans_features will try to check up to 3 models
# 28_CatBoost_KMeansFeatures mae 0.091026 trained in 103.14 seconds
# 33_CatBoost_KMeansFeatures mae 0.092392 trained in 55.0 seconds
# 26_CatBoost_KMeansFeatures mae 0.095084 trained in 32.49 seconds
# * Step insert_random_feature will try to check up to 1 model
# 28_CatBoost_GoldenFeatures_RandomFeature mae 0.091703 trained in 100.8 seconds
# Drop features ['random_feature']
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 27 models
# 62_CatBoost_GoldenFeatures mae 0.08527 trained in 59.0 seconds
# 63_CatBoost mae 0.085031 trained in 35.2 seconds
# 64_CatBoost_GoldenFeatures mae 0.083984 trained in 63.73 seconds
# 65_CatBoost_GoldenFeatures mae 0.090165 trained in 24.46 seconds
# 66_Xgboost mae 0.095713 trained in 10.56 seconds
# 67_Xgboost mae 0.089213 trained in 10.56 seconds
# 68_LightGBM mae 0.095376 trained in 9.94 seconds
# 69_LightGBM mae 0.09724 trained in 7.93 seconds
# 70_LightGBM mae 0.09379 trained in 11.84 seconds
# 71_LightGBM mae 0.09542 trained in 8.54 seconds
# 72_LightGBM mae 0.094437 trained in 8.98 seconds
# 73_Xgboost mae 0.114207 trained in 10.43 seconds
# 74_Xgboost mae 0.113285 trained in 11.29 seconds
# 75_Xgboost mae 0.11443 trained in 9.67 seconds
# 76_Xgboost mae 0.11341 trained in 10.08 seconds
# 77_RandomForest mae 0.150748 trained in 14.35 seconds
# 78_RandomForest mae 0.13377 trained in 16.32 seconds
# 79_RandomForest mae 0.168665 trained in 14.7 seconds
# 80_RandomForest mae 0.139221 trained in 16.68 seconds
# 81_RandomForest mae 0.197254 trained in 15.1 seconds
# 82_RandomForest mae 0.147804 trained in 16.09 seconds
# 83_ExtraTrees mae 0.261988 trained in 16.15 seconds
# 84_ExtraTrees mae 0.190886 trained in 14.6 seconds
# 85_ExtraTrees mae 0.312559 trained in 14.07 seconds
# 86_ExtraTrees mae 0.194175 trained in 14.12 seconds
# 87_ExtraTrees mae 0.30813 trained in 18.12 seconds
# 88_ExtraTrees mae 0.238404 trained in 18.17 seconds
# * Step hill_climbing_2 will try to check up to 28 models
# 89_CatBoost_GoldenFeatures mae 0.083281 trained in 96.65 seconds
# 90_CatBoost_GoldenFeatures mae 0.084958 trained in 83.07 seconds
# 91_CatBoost_GoldenFeatures mae 0.084315 trained in 76.74 seconds
# 92_CatBoost mae 0.0852 trained in 61.15 seconds
# 93_CatBoost mae 0.083965 trained in 55.27 seconds
# 94_Xgboost mae 0.088816 trained in 13.85 seconds
# 95_Xgboost mae 0.089951 trained in 12.94 seconds
# 96_LightGBM mae 0.09379 trained in 13.57 seconds
# 97_LightGBM mae 0.094437 trained in 10.82 seconds
# 98_LightGBM mae 0.094437 trained in 11.06 seconds
# 99_LightGBM mae 0.09485 trained in 10.88 seconds
# 100_Xgboost mae 0.093805 trained in 13.1 seconds
# 101_NeuralNetwork mae 0.137682 trained in 15.75 seconds
# 102_NeuralNetwork mae 0.138608 trained in 12.95 seconds
# 103_NeuralNetwork mae 0.126694 trained in 16.23 seconds
# 104_NeuralNetwork mae 0.14907 trained in 13.63 seconds
# 105_RandomForest mae 0.130124 trained in 18.74 seconds
# 106_RandomForest mae 0.136041 trained in 17.95 seconds
# 107_RandomForest mae 0.138046 trained in 16.89 seconds
# 108_RandomForest mae 0.144348 trained in 17.11 seconds
# 109_RandomForest mae 0.138139 trained in 17.98 seconds
# 110_RandomForest mae 0.142068 trained in 17.74 seconds
# 111_ExtraTrees mae 0.180008 trained in 16.25 seconds
# 112_ExtraTrees mae 0.179118 trained in 16.14 seconds
# 113_ExtraTrees mae 0.192244 trained in 16.37 seconds
# 114_ExtraTrees mae 0.194346 trained in 16.33 seconds
# 115_ExtraTrees mae 0.180814 trained in 16.34 seconds
# 116_ExtraTrees mae 0.213184 trained in 16.96 seconds
# * Step boost_on_errors will try to check up to 1 model
# 28_CatBoost_GoldenFeatures_BoostOnErrors mae 0.083144 trained in 116.09 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.080733 trained in 33.46 seconds
# * Step stack will try to check up to 59 models
# 28_CatBoost_GoldenFeatures_Stacked mae 0.078387 trained in 269.7 seconds
# 94_Xgboost_Stacked mae 0.078147 trained in 25.59 seconds
# 70_LightGBM_Stacked mae 0.077446 trained in 20.77 seconds
# 103_NeuralNetwork_Stacked mae 0.167912 trained in 19.3 seconds
# 105_RandomForest_Stacked mae 0.075608 trained in 27.82 seconds
# 112_ExtraTrees_Stacked mae 0.07693 trained in 22.86 seconds
# 89_CatBoost_GoldenFeatures_Stacked mae 0.078619 trained in 239.87 seconds
# 67_Xgboost_Stacked mae 0.07866 trained in 26.0 seconds
# 96_LightGBM_Stacked mae 0.077446 trained in 21.71 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.166156 trained in 18.09 seconds
# 78_RandomForest_Stacked mae 0.076435 trained in 30.39 seconds
# 111_ExtraTrees_Stacked mae 0.076275 trained in 22.73 seconds
# 93_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 22.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 95_Xgboost_Stacked mae 0.078588 trained in 20.85 seconds
# 72_LightGBM_Stacked mae 0.07799 trained in 16.35 seconds
# 58_NeuralNetwork_Stacked mae 0.378284 trained in 16.51 seconds
# 106_RandomForest_Stacked mae 0.076656 trained in 28.28 seconds
# 115_ExtraTrees_Stacked mae 0.077844 trained in 21.56 seconds
# 64_CatBoost_GoldenFeatures_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 8.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 3_Default_Xgboost_Stacked mae 0.07818 trained in 21.88 seconds
# 98_LightGBM_Stacked mae 0.07799 trained in 16.77 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.074534 trained in 45.18 seconds
# AutoML fit time: 3662.96 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/54/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.177388 trained in 1.42 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.630288 trained in 13.36 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.098918 trained in 16.49 seconds
# 3_Default_Xgboost mae 0.093007 trained in 17.01 seconds
# 4_Default_CatBoost mae 0.093505 trained in 20.11 seconds
# 5_Default_NeuralNetwork mae 0.133342 trained in 18.87 seconds
# 6_Default_RandomForest mae 0.167919 trained in 20.99 seconds
# 7_Default_ExtraTrees mae 0.297581 trained in 22.78 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.120136 trained in 15.24 seconds
# 8_Xgboost mae 0.134907 trained in 21.05 seconds
# 26_CatBoost mae 0.091835 trained in 23.15 seconds
# 35_RandomForest mae 0.164542 trained in 20.65 seconds
# 44_ExtraTrees mae 0.252761 trained in 20.16 seconds
# 53_NeuralNetwork mae 0.155468 trained in 17.9 seconds
# 18_LightGBM mae 0.097756 trained in 14.84 seconds
# 9_Xgboost mae 0.121972 trained in 16.69 seconds
# 27_CatBoost mae 0.09765 trained in 18.93 seconds
# 36_RandomForest mae 0.159798 trained in 24.09 seconds
# 45_ExtraTrees mae 0.267194 trained in 22.04 seconds
# 54_NeuralNetwork mae 0.143605 trained in 19.97 seconds
# 19_LightGBM mae 0.101383 trained in 16.35 seconds
# 10_Xgboost mae 0.123153 trained in 24.24 seconds
# 28_CatBoost mae 0.086177 trained in 55.92 seconds
# 37_RandomForest mae 0.238022 trained in 20.72 seconds
# 46_ExtraTrees mae 0.269307 trained in 20.41 seconds
# 55_NeuralNetwork mae 0.144896 trained in 20.82 seconds
# 20_LightGBM mae 0.101817 trained in 19.58 seconds
# 11_Xgboost mae 0.120857 trained in 17.92 seconds
# 29_CatBoost mae 0.100562 trained in 81.68 seconds
# 38_RandomForest mae 0.183174 trained in 21.45 seconds
# 47_ExtraTrees mae 0.283511 trained in 21.04 seconds
# 56_NeuralNetwork mae 0.149792 trained in 19.98 seconds
# 21_LightGBM mae 0.127961 trained in 16.41 seconds
# 12_Xgboost mae 0.116241 trained in 19.32 seconds
# 30_CatBoost mae 0.094107 trained in 38.89 seconds
# 39_RandomForest mae 0.228072 trained in 21.05 seconds
# 48_ExtraTrees mae 0.254221 trained in 20.08 seconds
# 57_NeuralNetwork mae 0.136689 trained in 20.06 seconds
# 22_LightGBM mae 0.096624 trained in 17.17 seconds
# 13_Xgboost mae 0.119618 trained in 19.46 seconds
# 31_CatBoost mae 0.098336 trained in 67.85 seconds
# 40_RandomForest mae 0.191764 trained in 25.76 seconds
# 49_ExtraTrees mae 0.298609 trained in 21.93 seconds
# 58_NeuralNetwork mae 0.130278 trained in 21.88 seconds
# 23_LightGBM mae 0.10309 trained in 17.61 seconds
# 14_Xgboost mae 0.103276 trained in 17.58 seconds
# 32_CatBoost mae 0.094724 trained in 21.35 seconds
# 41_RandomForest mae 0.134321 trained in 24.55 seconds
# 50_ExtraTrees mae 0.212572 trained in 22.16 seconds
# 59_NeuralNetwork mae 0.13287 trained in 19.62 seconds
# 24_LightGBM mae 0.092184 trained in 18.76 seconds
# 15_Xgboost mae 0.136656 trained in 25.49 seconds
# 33_CatBoost mae 0.085878 trained in 31.93 seconds
# 42_RandomForest mae 0.229417 trained in 23.94 seconds
# 51_ExtraTrees mae 0.359648 trained in 23.59 seconds
# 60_NeuralNetwork mae 0.144383 trained in 20.12 seconds
# 25_LightGBM mae 0.090483 trained in 17.84 seconds
# 16_Xgboost mae 0.119124 trained in 23.14 seconds
# 34_CatBoost mae 0.094914 trained in 32.41 seconds
# 43_RandomForest mae 0.194613 trained in 26.32 seconds
# 52_ExtraTrees mae 0.324359 trained in 25.51 seconds
# 61_NeuralNetwork mae 0.1324 trained in 20.68 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 월_multiply_시
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 시_multiply_기온
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 시_multiply_습도
# Add Golden Feature: 시_ratio_습도
# Add Golden Feature: 기온_ratio_시
# Add Golden Feature: 시_ratio_기온
# Add Golden Feature: 습도_ratio_시
# Created 10 Golden Features in 12.64 seconds.
# 33_CatBoost_GoldenFeatures mae 0.094135 trained in 51.11 seconds
# 28_CatBoost_GoldenFeatures mae 0.09011 trained in 109.55 seconds
# 25_LightGBM_GoldenFeatures mae 0.099594 trained in 18.62 seconds
# * Step kmeans_features will try to check up to 3 models
# 33_CatBoost_KMeansFeatures mae 0.090589 trained in 59.44 seconds
# 28_CatBoost_KMeansFeatures mae 0.090094 trained in 141.89 seconds
# 25_LightGBM_KMeansFeatures mae 0.09096 trained in 21.24 seconds
# * Step insert_random_feature will try to check up to 1 model
# 33_CatBoost_RandomFeature mae 0.093884 trained in 46.19 seconds
# Drop features ['random_feature']
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 26 models
# 62_CatBoost mae 0.087093 trained in 41.01 seconds
# 63_CatBoost mae 0.088441 trained in 25.84 seconds
# 64_CatBoost mae 0.088096 trained in 44.91 seconds
# 65_CatBoost mae 0.092204 trained in 87.77 seconds
# 66_LightGBM mae 0.091047 trained in 19.8 seconds
# 67_LightGBM mae 0.089178 trained in 23.65 seconds
# 68_LightGBM mae 0.091105 trained in 22.11 seconds
# 69_LightGBM mae 0.092369 trained in 19.46 seconds
# 70_Xgboost mae 0.098819 trained in 22.04 seconds
# 71_Xgboost mae 0.092225 trained in 23.33 seconds
# 72_Xgboost mae 0.103443 trained in 20.1 seconds
# 73_Xgboost mae 0.102874 trained in 20.43 seconds
# 74_Xgboost mae 0.117488 trained in 21.88 seconds
# 75_Xgboost mae 0.11653 trained in 22.43 seconds
# 76_NeuralNetwork mae 0.139958 trained in 22.42 seconds
# 77_RandomForest mae 0.150978 trained in 26.45 seconds
# 78_RandomForest mae 0.12559 trained in 26.75 seconds
# 79_RandomForest mae 0.186217 trained in 29.54 seconds
# 80_RandomForest mae 0.144953 trained in 28.77 seconds
# 81_RandomForest mae 0.219741 trained in 25.78 seconds
# 82_RandomForest mae 0.136341 trained in 27.67 seconds
# 83_ExtraTrees mae 0.255761 trained in 26.94 seconds
# 84_ExtraTrees mae 0.203542 trained in 28.14 seconds
# 85_ExtraTrees mae 0.318389 trained in 26.18 seconds
# * Step hill_climbing_2 will try to check up to 11 models
# 86_CatBoost mae 0.089168 trained in 28.77 seconds
# 87_CatBoost mae 0.08572 trained in 63.74 seconds
# 88_CatBoost mae 0.089054 trained in 34.73 seconds
# 89_LightGBM mae 0.088901 trained in 28.57 seconds
# 90_Xgboost mae 0.092382 trained in 27.2 seconds
# 91_Xgboost mae 0.104765 trained in 22.88 seconds
# 92_NeuralNetwork mae 0.13223 trained in 27.51 seconds
# 93_NeuralNetwork mae 0.204227 trained in 24.63 seconds
# * Step boost_on_errors will try to check up to 1 model
# 87_CatBoost_BoostOnErrors mae 0.085638 trained in 64.42 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.082012 trained in 22.08 seconds
# * Step stack will try to check up to 59 models
# 87_CatBoost_Stacked mae 0.081177 trained in 293.15 seconds
# 89_LightGBM_Stacked mae 0.082093 trained in 32.74 seconds
# 71_Xgboost_Stacked mae 0.082037 trained in 36.82 seconds
# 78_RandomForest_Stacked mae 0.078228 trained in 37.25 seconds
# 58_NeuralNetwork_Stacked mae 0.242835 trained in 30.83 seconds
# 84_ExtraTrees_Stacked mae 0.079567 trained in 31.73 seconds
# 33_CatBoost_Stacked mae 0.084046 trained in 94.77 seconds
# 67_LightGBM_Stacked mae 0.082374 trained in 29.49 seconds
# 90_Xgboost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 2.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 41_RandomForest_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 2.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 92_NeuralNetwork_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 2.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 50_ExtraTrees_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 1.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 28_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 30.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.07798 trained in 26.13 seconds
# AutoML fit time: 3667.03 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/55/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.019536 trained in 2.23 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.070281 trained in 22.45 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.012581 trained in 24.3 seconds
# 3_Default_Xgboost mae 0.011527 trained in 24.23 seconds
# 4_Default_CatBoost mae 0.011275 trained in 26.69 seconds
# 5_Default_NeuralNetwork mae 0.013345 trained in 27.19 seconds
# 6_Default_RandomForest mae 0.018532 trained in 28.3 seconds
# 7_Default_ExtraTrees mae 0.033483 trained in 28.44 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.0143 trained in 23.4 seconds
# 8_Xgboost mae 0.015541 trained in 30.53 seconds
# 26_CatBoost mae 0.011152 trained in 28.9 seconds
# 35_RandomForest mae 0.018797 trained in 29.14 seconds
# 44_ExtraTrees mae 0.030041 trained in 29.06 seconds
# 53_NeuralNetwork mae 0.027531 trained in 25.87 seconds
# 18_LightGBM mae 0.011808 trained in 22.99 seconds
# 9_Xgboost mae 0.014238 trained in 25.08 seconds
# 27_CatBoost mae 0.011215 trained in 26.66 seconds
# 36_RandomForest mae 0.016213 trained in 30.53 seconds
# 45_ExtraTrees mae 0.031779 trained in 32.05 seconds
# 54_NeuralNetwork mae 0.025415 trained in 26.94 seconds
# 19_LightGBM mae 0.01244 trained in 24.72 seconds
# 10_Xgboost mae 0.014469 trained in 32.02 seconds
# 28_CatBoost mae 0.010968 trained in 55.83 seconds
# 37_RandomForest mae 0.023029 trained in 28.56 seconds
# 46_ExtraTrees mae 0.04158 trained in 28.82 seconds
# 55_NeuralNetwork mae 0.014822 trained in 28.83 seconds
# 20_LightGBM mae 0.012526 trained in 28.31 seconds
# 11_Xgboost mae 0.013314 trained in 26.62 seconds
# 29_CatBoost mae 0.011912 trained in 71.38 seconds
# 38_RandomForest mae 0.019429 trained in 30.13 seconds
# 47_ExtraTrees mae 0.036757 trained in 31.05 seconds
# 56_NeuralNetwork mae 0.015487 trained in 27.25 seconds
# 21_LightGBM mae 0.015452 trained in 24.77 seconds
# 12_Xgboost mae 0.013629 trained in 26.45 seconds
# 30_CatBoost mae 0.01144 trained in 38.69 seconds
# 39_RandomForest mae 0.02262 trained in 29.87 seconds
# 48_ExtraTrees mae 0.04589 trained in 30.58 seconds
# 57_NeuralNetwork mae 0.014367 trained in 26.78 seconds
# 22_LightGBM mae 0.011974 trained in 25.5 seconds
# 13_Xgboost mae 0.012998 trained in 27.83 seconds
# 31_CatBoost mae 0.011597 trained in 67.77 seconds
# 40_RandomForest mae 0.019621 trained in 34.23 seconds
# 49_ExtraTrees mae 0.032213 trained in 30.38 seconds
# 58_NeuralNetwork mae 0.013969 trained in 27.31 seconds
# 23_LightGBM mae 0.012634 trained in 25.12 seconds
# 14_Xgboost mae 0.012691 trained in 25.92 seconds
# 32_CatBoost mae 0.011331 trained in 29.64 seconds
# 41_RandomForest mae 0.015245 trained in 33.02 seconds
# 50_ExtraTrees mae 0.025628 trained in 30.98 seconds
# 59_NeuralNetwork mae 0.014674 trained in 27.4 seconds
# 24_LightGBM mae 0.011611 trained in 25.7 seconds
# 15_Xgboost mae 0.016329 trained in 35.97 seconds
# 33_CatBoost mae 0.010833 trained in 35.12 seconds
# 42_RandomForest mae 0.023139 trained in 36.72 seconds
# 51_ExtraTrees mae 0.040106 trained in 30.81 seconds
# 60_NeuralNetwork mae 0.020338 trained in 29.45 seconds
# 25_LightGBM mae 0.011768 trained in 25.67 seconds
# 16_Xgboost mae 0.014004 trained in 33.76 seconds
# 34_CatBoost mae 0.011315 trained in 39.04 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_multiply_습도
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 시_ratio_기온
# Add Golden Feature: 기온_ratio_시
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 시_diff_주
# Add Golden Feature: 시_diff_풍속
# Created 10 Golden Features in 13.14 seconds.
# 33_CatBoost_GoldenFeatures mae 0.011311 trained in 57.34 seconds
# 28_CatBoost_GoldenFeatures mae 0.011349 trained in 118.15 seconds
# * Step kmeans_features will try to check up to 3 models
# 33_CatBoost_KMeansFeatures mae 0.011019 trained in 43.77 seconds
# 28_CatBoost_KMeansFeatures mae 0.01129 trained in 105.63 seconds
# * Step insert_random_feature will try to check up to 1 model
# 33_CatBoost_RandomFeature mae 0.01153 trained in 54.59 seconds
# Drop features ['random_feature']
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 27 models
# 61_CatBoost mae 0.010827 trained in 43.47 seconds
# 62_CatBoost mae 0.011082 trained in 32.38 seconds
# 63_CatBoost mae 0.010991 trained in 44.14 seconds
# 64_CatBoost mae 0.010925 trained in 54.95 seconds
# 65_CatBoost mae 0.011257 trained in 39.33 seconds
# 66_Xgboost mae 0.011591 trained in 28.81 seconds
# 67_LightGBM mae 0.012424 trained in 28.52 seconds
# 68_LightGBM mae 0.012029 trained in 27.27 seconds
# 69_LightGBM mae 0.013361 trained in 27.76 seconds
# 70_LightGBM mae 0.011808 trained in 27.21 seconds
# 71_Xgboost mae 0.012076 trained in 28.49 seconds
# 72_Xgboost mae 0.013321 trained in 27.73 seconds
# * Step hill_climbing_2 will try to check up to 24 models
# 73_CatBoost mae 0.011025 trained in 38.67 seconds
# 74_CatBoost mae 0.011059 trained in 34.08 seconds
# 75_CatBoost mae 0.01128 trained in 47.29 seconds
# 76_Xgboost mae 0.011361 trained in 30.1 seconds
# 77_Xgboost mae 0.011495 trained in 29.5 seconds
# 78_LightGBM mae 0.011611 trained in 28.28 seconds
# 79_LightGBM mae 0.011768 trained in 27.6 seconds
# 80_LightGBM mae 0.011768 trained in 27.73 seconds
# * Step boost_on_errors will try to check up to 1 model
# 61_CatBoost_BoostOnErrors mae 0.010814 trained in 42.67 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.010421 trained in 15.54 seconds
# * Step stack will try to check up to 56 models
# 61_CatBoost_Stacked mae 0.01073 trained in 84.66 seconds
# 76_Xgboost_Stacked mae 0.010633 trained in 37.83 seconds
# 24_LightGBM_Stacked mae 0.010828 trained in 32.75 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.044382 trained in 33.92 seconds
# 41_RandomForest_Stacked mae 0.010494 trained in 45.08 seconds
# 50_ExtraTrees_Stacked mae 0.010359 trained in 37.63 seconds
# 33_CatBoost_Stacked mae 0.010983 trained in 70.19 seconds
# 77_Xgboost_Stacked mae 0.010751 trained in 35.73 seconds
# 78_LightGBM_Stacked mae 0.010828 trained in 33.2 seconds
# 58_NeuralNetwork_Stacked mae 0.049087 trained in 37.22 seconds
# 36_RandomForest_Stacked mae 0.01041 trained in 39.38 seconds
# 44_ExtraTrees_Stacked mae 0.010447 trained in 37.15 seconds
# 64_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 15.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 3_Default_Xgboost_Stacked mae 0.010867 trained in 37.54 seconds
# 25_LightGBM_Stacked mae 0.010932 trained in 31.08 seconds
# 57_NeuralNetwork_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 1.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 6_Default_RandomForest_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 2.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 45_ExtraTrees_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 1.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 28_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 24.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.010233 trained in 21.49 seconds
# AutoML fit time: 3653.73 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/56/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.022 trained in 3.0 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.054507 trained in 31.17 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.010445 trained in 32.02 seconds
# 3_Default_Xgboost mae 0.009687 trained in 35.62 seconds
# 4_Default_CatBoost mae 0.009353 trained in 38.94 seconds
# 5_Default_NeuralNetwork mae 0.012741 trained in 33.27 seconds
# 6_Default_RandomForest mae 0.018752 trained in 36.65 seconds
# 7_Default_ExtraTrees mae 0.029753 trained in 37.19 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.01208 trained in 30.45 seconds
# 8_Xgboost mae 0.013436 trained in 39.0 seconds
# 26_CatBoost mae 0.009191 trained in 42.26 seconds
# 35_RandomForest mae 0.01909 trained in 37.53 seconds
# 44_ExtraTrees mae 0.027369 trained in 36.5 seconds
# 53_NeuralNetwork mae 0.01448 trained in 33.17 seconds
# 18_LightGBM mae 0.009813 trained in 31.4 seconds
# 9_Xgboost mae 0.01229 trained in 32.66 seconds
# 27_CatBoost mae 0.009728 trained in 36.21 seconds
# 36_RandomForest mae 0.016176 trained in 40.8 seconds
# 45_ExtraTrees mae 0.026249 trained in 40.76 seconds
# 54_NeuralNetwork mae 0.013939 trained in 34.7 seconds
# 19_LightGBM mae 0.01048 trained in 32.21 seconds
# 10_Xgboost mae 0.012684 trained in 39.4 seconds
# 28_CatBoost mae 0.008768 trained in 87.72 seconds
# 37_RandomForest mae 0.023248 trained in 36.39 seconds
# 46_ExtraTrees mae 0.033307 trained in 36.27 seconds
# 55_NeuralNetwork mae 0.01381 trained in 37.1 seconds
# 20_LightGBM mae 0.01052 trained in 35.37 seconds
# 11_Xgboost mae 0.01172 trained in 34.12 seconds
# 29_CatBoost mae 0.010191 trained in 66.58 seconds
# 38_RandomForest mae 0.019386 trained in 37.37 seconds
# 47_ExtraTrees mae 0.030076 trained in 37.59 seconds
# 56_NeuralNetwork mae 0.014484 trained in 35.2 seconds
# 21_LightGBM mae 0.01325 trained in 32.82 seconds
# 12_Xgboost mae 0.011709 trained in 36.0 seconds
# 30_CatBoost mae 0.009408 trained in 60.14 seconds
# 39_RandomForest mae 0.023499 trained in 37.83 seconds
# 48_ExtraTrees mae 0.036084 trained in 37.36 seconds
# 57_NeuralNetwork mae 0.013418 trained in 34.55 seconds
# 22_LightGBM mae 0.010333 trained in 32.77 seconds
# 13_Xgboost mae 0.011473 trained in 35.25 seconds
# 31_CatBoost mae 0.009982 trained in 48.79 seconds
# 40_RandomForest mae 0.019389 trained in 43.93 seconds
# 49_ExtraTrees mae 0.027131 trained in 38.22 seconds
# 58_NeuralNetwork mae 0.012569 trained in 37.01 seconds
# 23_LightGBM mae 0.011039 trained in 33.92 seconds
# 14_Xgboost mae 0.010888 trained in 33.99 seconds
# 32_CatBoost mae 0.009616 trained in 37.94 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 시_multiply_습도
# Add Golden Feature: 시_diff_풍속
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 시_diff_주
# Add Golden Feature: 기온_ratio_시
# Add Golden Feature: 시_ratio_기온
# Created 10 Golden Features in 12.71 seconds.
# 28_CatBoost_GoldenFeatures mae 0.009316 trained in 152.9 seconds
# * Step kmeans_features will try to check up to 3 models
# 28_CatBoost_KMeansFeatures mae 0.009605 trained in 152.18 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 366.0 seconds
# Please increase total_time_limit to at least (3715 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 34 models
# 59_CatBoost mae 0.008811 trained in 80.59 seconds
# 60_CatBoost mae 0.008843 trained in 82.06 seconds
# 61_CatBoost mae 0.009253 trained in 44.65 seconds
# 62_CatBoost mae 0.009023 trained in 49.91 seconds
# 63_CatBoost_GoldenFeatures mae 0.009499 trained in 127.22 seconds
# 64_CatBoost_GoldenFeatures mae 0.009393 trained in 122.53 seconds
# * Step hill_climbing_2 will try to check up to 27 models
# 65_CatBoost mae 0.009037 trained in 64.81 seconds
# 66_CatBoost mae 0.009066 trained in 66.02 seconds
# 67_CatBoost mae 0.009038 trained in 61.96 seconds
# 68_Xgboost mae 0.0097 trained in 41.61 seconds
# 69_Xgboost mae 0.009745 trained in 37.71 seconds
# * Step boost_on_errors will try to check up to 1 model
# 28_CatBoost_BoostOnErrors mae 0.008854 trained in 85.68 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.008611 trained in 8.04 seconds
# * Step stack will try to check up to 48 models
# 28_CatBoost_Stacked mae 0.008516 trained in 234.22 seconds
# 3_Default_Xgboost_Stacked mae 0.008753 trained in 41.62 seconds
# 18_LightGBM_Stacked mae 0.008805 trained in 34.36 seconds
# 58_NeuralNetwork_Stacked mae 0.046461 trained in 38.19 seconds
# 36_RandomForest_Stacked mae 0.008399 trained in 44.62 seconds
# 45_ExtraTrees_Stacked mae 0.008335 trained in 44.97 seconds
# 59_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 15.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 68_Xgboost_Stacked mae 0.00876 trained in 44.03 seconds
# 22_LightGBM_Stacked mae 0.008709 trained in 36.69 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.042902 trained in 38.78 seconds
# 6_Default_RandomForest_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 2.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 49_ExtraTrees_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 1.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 60_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 24.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.008238 trained in 10.97 seconds
# AutoML fit time: 3637.3 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/57/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.104123 trained in 3.59 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.45974 trained in 37.1 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.052474 trained in 40.76 seconds
# 3_Default_Xgboost mae 0.047108 trained in 40.37 seconds
# 4_Default_CatBoost mae 0.044991 trained in 43.06 seconds
# 5_Default_NeuralNetwork mae 0.070635 trained in 37.84 seconds
# 6_Default_RandomForest mae 0.095758 trained in 42.69 seconds
# 7_Default_ExtraTrees mae 0.154269 trained in 41.9 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.055694 trained in 37.41 seconds
# 8_Xgboost mae 0.073108 trained in 48.48 seconds
# 26_CatBoost mae 0.04393 trained in 49.23 seconds
# 35_RandomForest mae 0.094972 trained in 41.26 seconds
# 44_ExtraTrees mae 0.131609 trained in 41.61 seconds
# 53_NeuralNetwork mae 0.088637 trained in 36.51 seconds
# 18_LightGBM mae 0.04791 trained in 37.43 seconds
# 9_Xgboost mae 0.058576 trained in 38.98 seconds
# 27_CatBoost mae 0.045899 trained in 40.84 seconds
# 36_RandomForest mae 0.089697 trained in 45.62 seconds
# 45_ExtraTrees mae 0.150526 trained in 45.46 seconds
# 54_NeuralNetwork mae 0.115847 trained in 39.52 seconds
# 19_LightGBM mae 0.050678 trained in 39.63 seconds
# 10_Xgboost mae 0.06113 trained in 52.47 seconds
# 28_CatBoost mae 0.044886 trained in 94.8 seconds
# 37_RandomForest mae 0.12843 trained in 42.27 seconds
# 46_ExtraTrees mae 0.218063 trained in 41.61 seconds
# 55_NeuralNetwork mae 0.07064 trained in 43.59 seconds
# 20_LightGBM mae 0.054566 trained in 43.03 seconds
# 11_Xgboost mae 0.055267 trained in 41.23 seconds
# 29_CatBoost mae 0.050099 trained in 54.44 seconds
# 38_RandomForest mae 0.106531 trained in 47.12 seconds
# 47_ExtraTrees mae 0.156488 trained in 41.82 seconds
# 56_NeuralNetwork mae 0.076523 trained in 40.02 seconds
# 21_LightGBM mae 0.060181 trained in 37.89 seconds
# 12_Xgboost mae 0.06606 trained in 41.03 seconds
# 30_CatBoost mae 0.04502 trained in 69.12 seconds
# 39_RandomForest mae 0.124957 trained in 43.59 seconds
# 48_ExtraTrees mae 0.153023 trained in 42.35 seconds
# 57_NeuralNetwork mae 0.074711 trained in 39.21 seconds
# 22_LightGBM mae 0.047087 trained in 39.66 seconds
# 13_Xgboost mae 0.056229 trained in 42.98 seconds
# 31_CatBoost mae 0.047735 trained in 46.97 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 월_multiply_시
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 시_diff_풍속
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 시_diff_주
# Add Golden Feature: 기온_ratio_시
# Add Golden Feature: 시_ratio_기온
# Created 10 Golden Features in 13.32 seconds.
# 26_CatBoost_GoldenFeatures mae 0.049035 trained in 74.54 seconds
# 28_CatBoost_GoldenFeatures mae 0.048457 trained in 160.94 seconds
# * Step kmeans_features will try to check up to 3 models
# 26_CatBoost_KMeansFeatures mae 0.046992 trained in 64.98 seconds
# * Step insert_random_feature will try to check up to 1 model
# 26_CatBoost_RandomFeature mae 0.048049 trained in 50.83 seconds
# Drop features ['random_feature']
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 29 models
# 58_CatBoost mae 0.046482 trained in 50.02 seconds
# 59_CatBoost mae 0.04484 trained in 103.9 seconds
# 60_CatBoost mae 0.046534 trained in 46.6 seconds
# 61_LightGBM mae 0.047158 trained in 39.87 seconds
# 62_LightGBM mae 0.047179 trained in 39.87 seconds
# 63_Xgboost mae 0.050989 trained in 45.45 seconds
# 64_LightGBM mae 0.049191 trained in 38.86 seconds
# 65_LightGBM mae 0.049779 trained in 42.47 seconds
# 66_LightGBM mae 0.051782 trained in 41.12 seconds
# 67_Xgboost mae 0.055267 trained in 43.15 seconds
# * Step hill_climbing_2 will try to check up to 23 models
# 68_CatBoost mae 0.044089 trained in 61.4 seconds
# 69_CatBoost mae 0.045148 trained in 46.28 seconds
# 70_CatBoost mae 0.045172 trained in 75.27 seconds
# 71_CatBoost mae 0.044587 trained in 79.37 seconds
# * Step boost_on_errors will try to check up to 1 model
# 26_CatBoost_BoostOnErrors mae 0.045532 trained in 48.79 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.042869 trained in 7.7 seconds
# * Step stack will try to check up to 46 models
# 26_CatBoost_Stacked mae 0.046119 trained in 65.36 seconds
# 22_LightGBM_Stacked mae 0.045619 trained in 41.4 seconds
# 3_Default_Xgboost_Stacked mae 0.045091 trained in 46.13 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.135528 trained in 45.06 seconds
# 36_RandomForest_Stacked mae 0.043227 trained in 55.0 seconds
# 44_ExtraTrees_Stacked mae 0.044688 trained in 49.42 seconds
# 68_CatBoost_Stacked mae 0.04546 trained in 78.57 seconds
# 61_LightGBM_Stacked mae 0.04592 trained in 41.87 seconds
# 63_Xgboost_Stacked mae 0.045279 trained in 46.97 seconds
# 55_NeuralNetwork_Stacked mae 0.071411 trained in 47.33 seconds
# 35_RandomForest_Stacked mae 0.044557 trained in 52.58 seconds
# 45_ExtraTrees_Stacked mae 0.043432 trained in 49.56 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.042643 trained in 11.33 seconds
# AutoML fit time: 3638.49 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/58/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.012777 trained in 4.14 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.024738 trained in 43.27 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.00553 trained in 43.22 seconds
# 3_Default_Xgboost mae 0.005314 trained in 42.7 seconds
# 4_Default_CatBoost mae 0.00514 trained in 45.94 seconds
# 5_Default_NeuralNetwork mae 0.006415 trained in 44.37 seconds
# 6_Default_RandomForest mae 0.009597 trained in 47.3 seconds
# 7_Default_ExtraTrees mae 0.014292 trained in 46.39 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.0063 trained in 42.76 seconds
# 8_Xgboost mae 0.006757 trained in 45.88 seconds
# 26_CatBoost mae 0.005126 trained in 49.77 seconds
# 35_RandomForest mae 0.009721 trained in 47.89 seconds
# 44_ExtraTrees mae 0.01429 trained in 47.29 seconds
# 53_NeuralNetwork mae 0.007983 trained in 43.33 seconds
# 18_LightGBM mae 0.005463 trained in 41.53 seconds
# 9_Xgboost mae 0.006408 trained in 43.52 seconds
# 27_CatBoost mae 0.00523 trained in 45.68 seconds
# 36_RandomForest mae 0.007858 trained in 50.78 seconds
# 45_ExtraTrees mae 0.012826 trained in 49.57 seconds
# 54_NeuralNetwork mae 0.007256 trained in 44.79 seconds
# 19_LightGBM mae 0.005618 trained in 43.03 seconds
# 10_Xgboost mae 0.00625 trained in 48.87 seconds
# 28_CatBoost mae 0.004978 trained in 98.12 seconds
# 37_RandomForest mae 0.013576 trained in 48.38 seconds
# 46_ExtraTrees mae 0.017926 trained in 51.04 seconds
# 55_NeuralNetwork mae 0.007466 trained in 46.55 seconds
# 20_LightGBM mae 0.005508 trained in 45.5 seconds
# 11_Xgboost mae 0.006011 trained in 44.69 seconds
# 29_CatBoost mae 0.005559 trained in 60.89 seconds
# 38_RandomForest mae 0.01027 trained in 51.65 seconds
# 47_ExtraTrees mae 0.015554 trained in 48.52 seconds
# 56_NeuralNetwork mae 0.007336 trained in 46.22 seconds
# 21_LightGBM mae 0.006516 trained in 43.43 seconds
# 12_Xgboost mae 0.006368 trained in 45.91 seconds
# 30_CatBoost mae 0.00519 trained in 60.62 seconds
# 39_RandomForest mae 0.013489 trained in 48.57 seconds
# 48_ExtraTrees mae 0.017611 trained in 49.75 seconds
# 57_NeuralNetwork mae 0.007052 trained in 45.17 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 기온_diff_주
# Add Golden Feature: 월_multiply_기온
# Add Golden Feature: 월_sum_기온
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 풍속_sum_기온
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 시_diff_풍속
# Created 10 Golden Features in 13.81 seconds.
# 28_CatBoost_GoldenFeatures mae 0.005354 trained in 160.84 seconds
# * Step kmeans_features will try to check up to 3 models
# 28_CatBoost_KMeansFeatures mae 0.00541 trained in 149.55 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 430.0 seconds
# Please increase total_time_limit to at least (4357 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 33 models
# 58_CatBoost mae 0.00499 trained in 99.32 seconds
# 59_CatBoost mae 0.004974 trained in 92.02 seconds
# 60_CatBoost mae 0.005094 trained in 51.86 seconds
# 61_CatBoost mae 0.005095 trained in 53.26 seconds
# 62_CatBoost mae 0.005139 trained in 50.04 seconds
# 63_Xgboost mae 0.0054 trained in 45.97 seconds
# 64_LightGBM mae 0.005534 trained in 43.8 seconds
# 65_LightGBM mae 0.005432 trained in 47.1 seconds
# * Step hill_climbing_2 will try to check up to 20 models
# 66_CatBoost mae 0.005022 trained in 75.77 seconds
# 67_CatBoost mae 0.005012 trained in 81.99 seconds
# 68_CatBoost mae 0.005083 trained in 77.94 seconds
# 69_Xgboost mae 0.005537 trained in 47.2 seconds
# * Step boost_on_errors will try to check up to 1 model
# 59_CatBoost_BoostOnErrors mae 0.004969 trained in 88.58 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.004884 trained in 6.13 seconds
# * Step stack will try to check up to 43 models
# 59_CatBoost_Stacked mae 0.005056 trained in 204.18 seconds
# 3_Default_Xgboost_Stacked mae 0.005282 trained in 50.7 seconds
# 65_LightGBM_Stacked mae 0.005284 trained in 50.52 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.019321 trained in 47.49 seconds
# 36_RandomForest_Stacked mae 0.005045 trained in 57.49 seconds
# 45_ExtraTrees_Stacked mae 0.004896 trained in 52.17 seconds
# 28_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 16.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 63_Xgboost_Stacked mae 0.005198 trained in 50.9 seconds
# 18_LightGBM_Stacked mae 0.005154 trained in 45.37 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.00485 trained in 8.34 seconds
# AutoML fit time: 3613.77 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/59/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.150073 trained in 4.64 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.569057 trained in 48.52 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.067081 trained in 49.82 seconds
# 3_Default_Xgboost mae 0.055026 trained in 48.5 seconds
# 4_Default_CatBoost mae 0.053362 trained in 56.3 seconds
# 5_Default_NeuralNetwork mae 0.092682 trained in 47.28 seconds
# 6_Default_RandomForest mae 0.130892 trained in 52.82 seconds
# 7_Default_ExtraTrees mae 0.261162 trained in 54.36 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.083652 trained in 47.51 seconds
# 8_Xgboost mae 0.093556 trained in 54.28 seconds
# 26_CatBoost mae 0.051541 trained in 62.33 seconds
# 35_RandomForest mae 0.124289 trained in 52.61 seconds
# 44_ExtraTrees mae 0.212996 trained in 51.71 seconds
# 53_NeuralNetwork mae 0.113147 trained in 48.2 seconds
# 18_LightGBM mae 0.056278 trained in 46.35 seconds
# 9_Xgboost mae 0.083642 trained in 48.75 seconds
# 27_CatBoost mae 0.054574 trained in 53.95 seconds
# 36_RandomForest mae 0.114691 trained in 54.05 seconds
# 45_ExtraTrees mae 0.231163 trained in 54.43 seconds
# 54_NeuralNetwork mae 0.097449 trained in 49.52 seconds
# 19_LightGBM mae 0.063663 trained in 50.0 seconds
# 10_Xgboost mae 0.08183 trained in 61.72 seconds
# 28_CatBoost mae 0.052169 trained in 102.04 seconds
# 37_RandomForest mae 0.191403 trained in 53.73 seconds
# 46_ExtraTrees mae 0.280619 trained in 52.09 seconds
# 55_NeuralNetwork mae 0.087309 trained in 53.51 seconds
# 20_LightGBM mae 0.067323 trained in 54.2 seconds
# 11_Xgboost mae 0.073359 trained in 51.19 seconds
# 29_CatBoost mae 0.060093 trained in 58.26 seconds
# ...
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/68/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.101217 trained in 9.69 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 5-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.244488 trained in 56.55 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.036859 trained in 53.13 seconds
# 3_Default_Xgboost mae 0.035225 trained in 52.45 seconds
# 4_Default_CatBoost mae 0.030483 trained in 54.68 seconds
# 5_Default_NeuralNetwork mae 0.050673 trained in 50.38 seconds
# 6_Default_RandomForest mae 0.090297 trained in 51.04 seconds
# 7_Default_ExtraTrees mae 0.109223 trained in 52.26 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.036983 trained in 50.49 seconds
# 8_Xgboost mae 0.048005 trained in 52.4 seconds
# 26_CatBoost mae 0.029928 trained in 56.9 seconds
# 35_RandomForest mae 0.092654 trained in 52.76 seconds
# 44_ExtraTrees mae 0.103515 trained in 51.08 seconds
# 53_NeuralNetwork mae 0.060615 trained in 50.11 seconds
# 18_LightGBM mae 0.033403 trained in 49.67 seconds
# 9_Xgboost mae 0.038011 trained in 50.31 seconds
# 27_CatBoost mae 0.031079 trained in 53.17 seconds
# 36_RandomForest mae 0.075859 trained in 56.4 seconds
# 45_ExtraTrees mae 0.102196 trained in 53.76 seconds
# 54_NeuralNetwork mae 0.048043 trained in 50.67 seconds
# 19_LightGBM mae 0.035339 trained in 51.19 seconds
# 10_Xgboost mae 0.039767 trained in 56.74 seconds
# 28_CatBoost mae 0.030329 trained in 116.16 seconds
# 37_RandomForest mae 0.106267 trained in 51.44 seconds
# 46_ExtraTrees mae 0.135332 trained in 52.05 seconds
# 55_NeuralNetwork mae 0.053919 trained in 52.15 seconds
# 20_LightGBM mae 0.038338 trained in 53.89 seconds
# 11_Xgboost mae 0.037284 trained in 51.75 seconds
# 29_CatBoost mae 0.035239 trained in 54.83 seconds
# 38_RandomForest mae 0.091838 trained in 51.97 seconds
# 47_ExtraTrees mae 0.116671 trained in 51.7 seconds
# 56_NeuralNetwork mae 0.066671 trained in 50.89 seconds
# 21_LightGBM mae 0.041382 trained in 50.42 seconds
# 12_Xgboost mae 0.048339 trained in 52.94 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_multiply_시
# Add Golden Feature: 시_multiply_기온
# Add Golden Feature: 시_sum_기온
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_multiply_습도
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 시_diff_풍속
# Add Golden Feature: 시_ratio_월
# Created 10 Golden Features in 15.98 seconds.
# 26_CatBoost_GoldenFeatures mae 0.033478 trained in 85.8 seconds
# 28_CatBoost_GoldenFeatures mae 0.033361 trained in 158.61 seconds
# Skip kmeans_features because of the time limit.
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 380.0 seconds
# Please increase total_time_limit to at least (3863 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 27 models
# 57_CatBoost mae 0.030692 trained in 58.13 seconds
# 58_CatBoost mae 0.030115 trained in 63.92 seconds
# 59_CatBoost mae 0.03054 trained in 89.96 seconds
# 60_CatBoost mae 0.031268 trained in 55.01 seconds
# 61_CatBoost mae 0.029851 trained in 59.43 seconds
# 62_LightGBM mae 0.033431 trained in 52.23 seconds
# 63_LightGBM mae 0.035176 trained in 49.84 seconds
# 64_Xgboost mae 0.034927 trained in 54.1 seconds
# 65_Xgboost mae 0.036603 trained in 52.7 seconds
# 66_LightGBM mae 0.035326 trained in 50.97 seconds
# * Step hill_climbing_2 will try to check up to 31 models
# 67_CatBoost mae 0.029298 trained in 66.75 seconds
# 68_CatBoost mae 0.030406 trained in 55.8 seconds
# 69_CatBoost mae 0.029113 trained in 69.42 seconds
# 70_CatBoost mae 0.030589 trained in 57.63 seconds
# * Step boost_on_errors will try to check up to 1 model
# 69_CatBoost_BoostOnErrors mae 0.029807 trained in 68.84 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.028476 trained in 5.67 seconds
# * Step stack will try to check up to 41 models
# 69_CatBoost_Stacked mae 0.031176 trained in 63.7 seconds
# 18_LightGBM_Stacked mae 0.030025 trained in 49.77 seconds
# 64_Xgboost_Stacked mae 0.030488 trained in 51.69 seconds
# 54_NeuralNetwork_Stacked mae 0.244481 trained in 50.36 seconds
# 36_RandomForest_Stacked mae 0.029255 trained in 56.29 seconds
# 45_ExtraTrees_Stacked mae 0.029066 trained in 54.26 seconds
# 67_CatBoost_Stacked mae 0.031077 trained in 64.46 seconds
# 62_LightGBM_Stacked mae 0.029985 trained in 49.5 seconds
# 3_Default_Xgboost_Stacked mae 0.030769 trained in 51.01 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.10701 trained in 52.68 seconds
# 6_Default_RandomForest_Stacked mae 0.030198 trained in 58.16 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.028368 trained in 8.56 seconds
# AutoML fit time: 3624.55 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/69/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.073784 trained in 10.05 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 5-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.254291 trained in 59.63 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.035595 trained in 51.96 seconds
# 3_Default_Xgboost mae 0.028484 trained in 51.5 seconds
# 4_Default_CatBoost mae 0.0285 trained in 55.31 seconds
# 5_Default_NeuralNetwork mae 0.043951 trained in 51.07 seconds
# 6_Default_RandomForest mae 0.064538 trained in 54.99 seconds
# 7_Default_ExtraTrees mae 0.13082 trained in 53.45 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.043253 trained in 51.87 seconds
# 8_Xgboost mae 0.049641 trained in 55.63 seconds
# 26_CatBoost mae 0.028314 trained in 58.54 seconds
# 35_RandomForest mae 0.066899 trained in 52.96 seconds
# 44_ExtraTrees mae 0.111015 trained in 53.11 seconds
# 53_NeuralNetwork mae 0.053946 trained in 51.23 seconds
# 18_LightGBM mae 0.029999 trained in 50.38 seconds
# 9_Xgboost mae 0.042467 trained in 52.14 seconds
# 27_CatBoost mae 0.029774 trained in 53.48 seconds
# 36_RandomForest mae 0.054972 trained in 54.52 seconds
# 45_ExtraTrees mae 0.11868 trained in 54.35 seconds
# 54_NeuralNetwork mae 0.052179 trained in 51.84 seconds
# 19_LightGBM mae 0.033213 trained in 52.72 seconds
# 10_Xgboost mae 0.043611 trained in 56.19 seconds
# 28_CatBoost mae 0.027579 trained in 77.97 seconds
# 37_RandomForest mae 0.089855 trained in 53.7 seconds
# 46_ExtraTrees mae 0.157446 trained in 53.34 seconds
# 55_NeuralNetwork mae 0.049889 trained in 53.28 seconds
# 20_LightGBM mae 0.035087 trained in 53.74 seconds
# 11_Xgboost mae 0.037742 trained in 52.77 seconds
# 29_CatBoost mae 0.031654 trained in 55.39 seconds
# 38_RandomForest mae 0.069306 trained in 54.05 seconds
# 47_ExtraTrees mae 0.131841 trained in 54.31 seconds
# 56_NeuralNetwork mae 0.048501 trained in 53.12 seconds
# 21_LightGBM mae 0.046699 trained in 52.5 seconds
# 12_Xgboost mae 0.041226 trained in 52.64 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 시_diff_주
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 시_diff_풍속
# Add Golden Feature: 시_multiply_습도
# Add Golden Feature: 시_ratio_기온
# Add Golden Feature: 기온_ratio_시
# Created 10 Golden Features in 16.56 seconds.
# 28_CatBoost_GoldenFeatures mae 0.029527 trained in 147.93 seconds
# * Step kmeans_features will try to check up to 3 models
# 28_CatBoost_KMeansFeatures mae 0.031311 trained in 108.9 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 420.0 seconds
# Please increase total_time_limit to at least (4257 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 26 models
# 57_CatBoost mae 0.027766 trained in 72.91 seconds
# 58_CatBoost mae 0.028963 trained in 55.84 seconds
# 59_CatBoost mae 0.027665 trained in 65.1 seconds
# 60_Xgboost mae 0.029014 trained in 53.82 seconds
# 61_Xgboost mae 0.028402 trained in 53.05 seconds
# 62_CatBoost mae 0.030104 trained in 54.82 seconds
# 63_CatBoost mae 0.028127 trained in 57.26 seconds
# 64_LightGBM mae 0.029654 trained in 51.98 seconds
# 65_LightGBM mae 0.030725 trained in 51.85 seconds
# 66_LightGBM mae 0.033813 trained in 52.34 seconds
# * Step hill_climbing_2 will try to check up to 29 models
# 67_CatBoost mae 0.028123 trained in 65.52 seconds
# 68_CatBoost mae 0.027332 trained in 73.34 seconds
# 69_CatBoost mae 0.028603 trained in 57.82 seconds
# 70_CatBoost mae 0.028422 trained in 63.54 seconds
# * Step boost_on_errors will try to check up to 1 model
# 68_CatBoost_BoostOnErrors mae 0.02733 trained in 70.17 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.025802 trained in 5.68 seconds
# * Step stack will try to check up to 41 models
# 68_CatBoost_Stacked mae 0.027789 trained in 89.11 seconds
# 61_Xgboost_Stacked mae 0.027841 trained in 56.47 seconds
# 64_LightGBM_Stacked mae 0.027155 trained in 52.24 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.159431 trained in 53.35 seconds
# 36_RandomForest_Stacked mae 0.026365 trained in 58.06 seconds
# 44_ExtraTrees_Stacked mae 0.027006 trained in 56.95 seconds
# 28_CatBoost_Stacked mae 0.026559 trained in 140.79 seconds
# 3_Default_Xgboost_Stacked mae 0.028048 trained in 55.88 seconds
# 18_LightGBM_Stacked mae 0.027055 trained in 52.02 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.025537 trained in 8.13 seconds
# AutoML fit time: 3638.46 seconds
# AutoML best model: Ensemble_Stacked
# AutoML directory: ../model/split_build/70/
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Xgboost', 'Random Forest', 'Extra Trees', 'LightGBM', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree mae 0.139757 trained in 10.64 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 5-fold CV Shuffle
# * Step simple_algorithms will try to check up to 1 model
# 1_Baseline mae 0.349485 trained in 61.54 seconds
# * Step default_algorithms will try to check up to 6 models
# 2_Default_LightGBM mae 0.072536 trained in 53.79 seconds
# 3_Default_Xgboost mae 0.067799 trained in 54.64 seconds
# 4_Default_CatBoost mae 0.069461 trained in 56.6 seconds
# 5_Default_NeuralNetwork mae 0.093381 trained in 53.17 seconds
# 6_Default_RandomForest mae 0.125005 trained in 57.0 seconds
# 7_Default_ExtraTrees mae 0.192758 trained in 55.19 seconds
# * Step not_so_random will try to check up to 54 models
# 17_LightGBM mae 0.098628 trained in 53.29 seconds
# 8_Xgboost mae 0.102073 trained in 54.64 seconds
# 26_CatBoost mae 0.065968 trained in 59.96 seconds
# 35_RandomForest mae 0.125648 trained in 55.71 seconds
# 44_ExtraTrees mae 0.173374 trained in 55.89 seconds
# 53_NeuralNetwork mae 0.131945 trained in 53.23 seconds
# 18_LightGBM mae 0.068279 trained in 52.5 seconds
# 9_Xgboost mae 0.101358 trained in 53.46 seconds
# 27_CatBoost mae 0.069431 trained in 57.03 seconds
# 36_RandomForest mae 0.114784 trained in 56.5 seconds
# 45_ExtraTrees mae 0.170075 trained in 57.75 seconds
# 54_NeuralNetwork mae 0.101082 trained in 54.41 seconds
# 19_LightGBM mae 0.079185 trained in 54.06 seconds
# 10_Xgboost mae 0.093515 trained in 56.49 seconds
# 28_CatBoost mae 0.061982 trained in 92.0 seconds
# 37_RandomForest mae 0.153365 trained in 56.22 seconds
# 46_ExtraTrees mae 0.217182 trained in 55.41 seconds
# 55_NeuralNetwork mae 0.104811 trained in 58.78 seconds
# 20_LightGBM mae 0.072934 trained in 55.6 seconds
# 11_Xgboost mae 0.096698 trained in 54.2 seconds
# 29_CatBoost mae 0.077801 trained in 56.77 seconds
# 38_RandomForest mae 0.13278 trained in 55.87 seconds
# 47_ExtraTrees mae 0.184453 trained in 56.48 seconds
# 56_NeuralNetwork mae 0.11402 trained in 55.27 seconds
# 21_LightGBM mae 0.105374 trained in 53.35 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: 월_sum_시
# Add Golden Feature: 시_diff_월
# Add Golden Feature: 월_multiply_시
# Add Golden Feature: 시_diff_주
# Add Golden Feature: 풍속_sum_시
# Add Golden Feature: 시_ratio_월
# Add Golden Feature: 월_ratio_시
# Add Golden Feature: 시_diff_풍속
# Add Golden Feature: 시_multiply_습도
# Add Golden Feature: 기온_ratio_시
# Created 10 Golden Features in 16.46 seconds.
# 28_CatBoost_GoldenFeatures mae 0.069546 trained in 120.26 seconds
# * Step kmeans_features will try to check up to 3 models
# 28_CatBoost_KMeansFeatures mae 0.068508 trained in 120.8 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 462.0 seconds
# Please increase total_time_limit to at least (4679 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 29 models
# 57_CatBoost mae 0.061433 trained in 92.82 seconds
# 58_CatBoost mae 0.068392 trained in 53.65 seconds
# 59_Xgboost mae 0.065717 trained in 51.37 seconds
# 60_LightGBM mae 0.068279 trained in 48.75 seconds
# 61_CatBoost mae 0.068314 trained in 126.75 seconds
# 62_LightGBM mae 0.072536 trained in 55.11 seconds
# 63_LightGBM mae 0.072536 trained in 55.28 seconds
# 64_LightGBM mae 0.072934 trained in 55.79 seconds
# * Step hill_climbing_2 will try to check up to 28 models
# 65_CatBoost mae 0.062764 trained in 71.62 seconds
# 66_CatBoost mae 0.064049 trained in 74.32 seconds
# 67_Xgboost mae 0.069393 trained in 55.67 seconds
# 68_CatBoost mae 0.064954 trained in 66.91 seconds
# * Step boost_on_errors will try to check up to 1 model
# 57_CatBoost_BoostOnErrors mae 0.06121 trained in 90.69 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 0.059891 trained in 5.13 seconds
# * Step stack will try to check up to 41 models
# 57_CatBoost_Stacked mae 0.056747 trained in 148.46 seconds
# 59_Xgboost_Stacked mae 0.06009 trained in 57.35 seconds
# 18_LightGBM_Stacked mae 0.059933 trained in 54.27 seconds
# 5_Default_NeuralNetwork_Stacked mae 0.15403 trained in 56.38 seconds
# 36_RandomForest_Stacked mae 0.058411 trained in 57.99 seconds
# 45_ExtraTrees_Stacked mae 0.058343 trained in 59.95 seconds
# 28_CatBoost_Stacked mae 0.058642 trained in 151.01 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 0.056346 trained in 6.89 seconds
# AutoML fit time: 3611.76 seconds
# AutoML best model: Ensemble_Stacked

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('../data/sample_submission.csv')
submission
# Out:
#          num_date_time  answer
# 0        1_20220825 00       0
# 1        1_20220825 01       0
# 2        1_20220825 02       0
# 3        1_20220825 03       0
# 4        1_20220825 04       0
# ...                ...     ...
# 16795  100_20220831 19       0
# 16796  100_20220831 20       0
# 16797  100_20220831 21       0
# 16798  100_20220831 22       0
# 16799  100_20220831 23       0
#
# [16800 rows x 2 columns]

# %% [markdown]
# ## Data Collecting

# %%
preds = pd.DataFrame()
for i in tqdm.notebook.tqdm(range(1, 101)):
    # load data
    tmp = pd.read_csv('../data/split_build/split_build'+str(i)+'.csv')
    
    # merging
    preds = pd.concat([preds, tmp], ignore_index=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
preds.columns = ['pred']

# %%
submission['answer'] = preds['pred']**(1/boxcox)
submission
# Out:
#          num_date_time       answer
# 0        1_20220825 00  2014.297444
# 1        1_20220825 01  2023.343391
# 2        1_20220825 02  1855.747162
# 3        1_20220825 03  1808.738063
# 4        1_20220825 04  1835.059301
# ...                ...          ...
# 16795  100_20220831 19   876.176108
# 16796  100_20220831 20   779.115975
# 16797  100_20220831 21   698.410587
# 16798  100_20220831 22   639.890263
# 16799  100_20220831 23   531.864251
#
# [16800 rows x 2 columns]

# %%
submission.to_csv('../data/AutoML_0.21_NA0_split_build.csv', index=False)
